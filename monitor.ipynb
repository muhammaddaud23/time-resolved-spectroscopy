# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np

# %%
hdul = fits.open("monitor.lc")
data = hdul[1].data
count = data['COUNTS']
time = data['TIME']

# %%
#No 1
fig,ax = plt.subplots(figsize=(15,10))
ax.scatter(time,count,s=2,color='black')
ax.set_xlabel('Waktu',fontsize=20)
ax.set_ylabel('Jumlah Count',fontsize=20)
#plt.axvline(x=245157280.87843037,c='red',ls='--')
#plt.axvline(x=245157264.87843037,c='red',ls='--')
plt.axvline(x=245157255.12843037,c='blue',ls='--')
plt.axvline(x=245157271.12843037,c='blue',ls='--')
#plt.axvline(x=245157317.37843037,c='green',ls='--')
ax.set_xlim([245157250.12843037,245157341.12843037])
# Out:
# (245157250.12843037, 245157341.12843037)

# %%
#No 2 FS4f_e9f2470-e9f30f7
fig,ax = plt.subplots(figsize=(15,10))
ax.scatter(time,count,s=2,color='black')
ax.set_xlabel('Waktu',fontsize=20)
ax.set_ylabel('Jumlah Count',fontsize=20)
#plt.axvline(x=245157280.87843037,c='red',ls='--')
#plt.axvline(x=245157264.87843037,c='red',ls='--')
plt.axvline(x=245312710.12843037,c='blue',ls='--')
plt.axvline(x=245312726.12843037,c='blue',ls='--')
#plt.axvline(x=245157317.37843037,c='green',ls='--')
ax.set_xlim([245312700.12843037,245312770.12843037])
# Out:
# (245312700.12843037, 245312770.12843037)

# %%
#No 3 FS4f_ea089d0-ea09790
fig,ax = plt.subplots(figsize=(15,10))
ax.scatter(time,count,s=2,color='black')
ax.set_xlabel('Waktu',fontsize=20)
ax.set_ylabel('Jumlah Count',fontsize=20)
#plt.axvline(x=245157280.87843037,c='red',ls='--')
#plt.axvline(x=245157264.87843037,c='red',ls='--')
plt.axvline(x=245404150.37843037,c='blue',ls='--')
plt.axvline(x=245404166.37843037,c='blue',ls='--')
#plt.axvline(x=245157317.37843037,c='green',ls='--')
ax.set_xlim([245404143.37843037,245404200.37843037])
# Out:
# (245404143.37843037, 245404200.37843037)

# %%
#No 4 FS4f_ea0a010-ea0add4
fig,ax = plt.subplots(figsize=(15,10))
ax.scatter(time,count,s=2,color='black')
ax.set_xlabel('Waktu',fontsize=20)
ax.set_ylabel('Jumlah Count',fontsize=20)
#plt.axvline(x=245157280.87843037,c='red',ls='--')
#plt.axvline(x=245157264.87843037,c='red',ls='--')
plt.axvline(x=245410740.12843037,c='blue',ls='--')
plt.axvline(x=245410756.12843037,c='blue',ls='--')
#plt.axvline(x=245157317.37843037,c='green',ls='--')
ax.set_xlim([245410720.12843037,245410870.12843037])
# Out:
# (245410720.12843037, 245410870.12843037)

# %%
#No 5 FS4f_ea32820-ea335a3
fig,ax = plt.subplots(figsize=(15,10))
ax.scatter(time,count,s=2,color='black')
ax.set_xlabel('Waktu',fontsize=20)
ax.set_ylabel('Jumlah Count',fontsize=20)
#plt.axvline(x=245157280.87843037,c='red',ls='--')
#plt.axvline(x=245157264.87843037,c='red',ls='--')
plt.axvline(x=245576562.12843037,c='blue',ls='--')
plt.axvline(x=245576578.12843037,c='blue',ls='--')
#plt.axvline(x=245157317.37843037,c='green',ls='--')
ax.set_xlim([245576560.12843037,245576640.12843037])
# Out:
# (245576560.12843037, 245576640.12843037)

# %%
#No 6 FS4f_1e3563b0-1e357132
fig,ax = plt.subplots(figsize=(15,10))
ax.scatter(time,count,s=2,color='black')
ax.set_xlabel('Waktu',fontsize=20)
ax.set_ylabel('Jumlah Count',fontsize=20)
#plt.axvline(x=245157280.87843037,c='red',ls='--')
#plt.axvline(x=245157264.87843037,c='red',ls='--')
plt.axvline(x=506818350.87842846,c='blue',ls='--')
plt.axvline(x=506818366.87842846,c='blue',ls='--')
plt.axvline(x=506818375.37842846,c='green',ls='--')
ax.set_xlim([506818338.87842846,506818390.87842846])
# Out:
# (506818338.87842846, 506818390.87842846)

# %%
#No 7 FS4f_1e392eb0-1e393c36
fig,ax = plt.subplots(figsize=(15,10))
ax.scatter(time,count,s=2,color='black')
ax.set_xlabel('Waktu',fontsize=20)
ax.set_ylabel('Jumlah Count',fontsize=20)
#plt.axvline(x=245157280.87843037,c='red',ls='--')
#plt.axvline(x=245157264.87843037,c='red',ls='--')
plt.axvline(x=507064930.87842846,c='blue',ls='--')
plt.axvline(x=507064946.87842846,c='blue',ls='--')
plt.axvline(x=507064985.37842846,c='green',ls='--')
ax.set_xlim([507064929.87842846,507065000.87842846])
# Out:
# (507064929.87842846, 507065000.87842846)

# %%
#No 8 FS4f_1e489e00-1e48ac3f
fig,ax = plt.subplots(figsize=(15,10))
ax.scatter(time,count,s=2,color='black')
ax.set_xlabel('Waktu',fontsize=20)
ax.set_ylabel('Jumlah Count',fontsize=20)
#plt.axvline(x=245157280.87843037,c='red',ls='--')
#plt.axvline(x=245157264.87843037,c='red',ls='--')
plt.axvline(x=508075845.62842846,c='blue',ls='--')
plt.axvline(x=508075861.62842846,c='blue',ls='--')
plt.axvline(x=508075901.37842846,c='green',ls='--')
ax.set_xlim([508075843.62842846,508075923.62842846])
# Out:
# (508075843.62842846, 508075923.62842846)

# %%
#No 9 FS4f_1e4ebdc0-1e4ecb81
fig,ax = plt.subplots(figsize=(15,10))
ax.scatter(time,count,s=2,color='black')
ax.set_xlabel('Waktu',fontsize=20)
ax.set_ylabel('Jumlah Count',fontsize=20)
#plt.axvline(x=245157280.87843037,c='red',ls='--')
#plt.axvline(x=245157264.87843037,c='red',ls='--')
plt.axvline(x=508478860.87842846,c='blue',ls='--')
plt.axvline(x=508478876.87842846,c='blue',ls='--')
plt.axvline(x=508478912.37842846,c='green',ls='--')
ax.set_xlim([508478857.87842846,508478937.87842846])
# Out:
# (508478857.87842846, 508478937.87842846)

# %%
np.where(count==max(count))
# Out:
# (array([4575]),)

# %%
time[4575]
# Out:
# 245157311.12843037

# %%
0.25*max(count)
# Out:
# 195.0

# %%
x = count.mean()
x
# Out:
# 91.18429003021149

# %%
import statistics as sta

# %%
std = sta.stdev(count)
std
# Out:
# 24.710414858659643

# %%
a = np.where(time==245157255.12843037)[0][0]
b = np.where(time==245157271.12843037)[0][0]

# %%
for i in range(a,b):
    if count[i] > x+std or count[i] < x-std:
        print('not good')
        print(time[i])
    else:
        #print(count[i])
        pass
